# %% [markdown]
# # My First Notebook

# %%
45 + 72

# %% [markdown]
# This is a note

# %%
45 + 70

# %%
5 * (12.7 - 4) / 2

# %%
5 * 12.7 - 4 / 2

# %%
5 * 12.7 - 4 / 2

# %%
5 * (3 + 4)

# %%
5 * 3 + 4
